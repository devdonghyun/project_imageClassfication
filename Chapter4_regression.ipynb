# %%
import matplotlib.pyplot as plt

population_inc = [0.3, -0.78, 1.26, 0.03, 1.11, 15.17, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
population_old = [12.27, 14.44, 11.87, 18.75, 17.52, 9.29, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

plt.plot(population_inc, population_old, 'bo')
plt.xlabel('Population Growth Rate')
plt.ylabel('Elderly Population Rate')
plt.show()

# %% [markdown]
# outlier: 극단치(일반적인 경향에서 벗어나는 사례)
# -> 데이터의 일반적인 경향을 파악하기 위해 극단치는 제거하는 것이 좋음

# %%
#Remove Outlier

import matplotlib.pyplot as plt

population_inc = [0.3, -0.78, 1.26, 0.03, 1.11, 15.17, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
population_old = [12.27, 14.44, 11.87, 18.75, 17.52, 9.29, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

population_inc =  population_inc[:5] + population_inc[6:]
population_old = population_old[:5] + population_old[6:]
plt.plot(population_inc, population_old, 'bo')
plt.xlabel('Population Growth Rate')
plt.ylabel('Elderly Population Rate')
plt.show()

# %%
#Least Square Method
## 1.Linear_Regression

import tensorflow as tf
import numpy as np
import random
import matplotlib.pyplot as plt

X = [0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
Y = [12.27, 14.44, 11.87, 18.75, 17.52, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

a = tf.Variable(random.random())
b = tf.Variable(random.random())

def compute_loss():
    y_pred = a*X + b
    loss = tf.reduce_mean((Y-y_pred)**2)
    return loss

optimizer = tf.optimizers.Adam(lr=0.07)
for i in range(2000):
    optimizer.minimize(compute_loss, var_list=[a,b])
    
    if i % 100 == 99:
        print(i, 'a:', a.numpy(), 'b:', b.numpy(), 'loss:', compute_loss().numpy())

line_x = np.arange(min(X), max(X), 0.01)
line_y = a * line_x + b

# 그래프를 그립니다.
plt.plot(line_x,line_y,'r-')
plt.plot(X,Y,'bo')
plt.xlabel('Population Growth Rate (%)')
plt.ylabel('Elderly Population Rate (%)')
plt.show()
# Out:
# 99 a: 0.13333207 b: 6.4757237 loss: 94.10692
# 199 a: -0.107654385 b: 11.00846 loss: 31.454008
# 299 a: -0.25029013 b: 13.686945 loss: 13.7014885
# 399 a: -0.31869966 b: 14.971829 loss: 10.266166
# 499 a: -0.34507963 b: 15.4673195 loss: 9.821512
# 599 a: -0.35328034 b: 15.621357 loss: 9.783098
# 699 a: -0.3553405 b: 15.660048 loss: 9.7808895
# 799 a: -0.35575742 b: 15.667874 loss: 9.780806
# 899 a: -0.35582453 b: 15.669139 loss: 9.780804
# 999 a: -0.35583326 b: 15.669302 loss: 9.780804
# 1099 a: -0.3558333 b: 15.669302 loss: 9.780805
# 1199 a: -0.35583326 b: 15.669302 loss: 9.780804
# 1299 a: -0.35583323 b: 15.669302 loss: 9.780804
# 1399 a: -0.3558333 b: 15.669302 loss: 9.780805
# 1499 a: -0.35583323 b: 15.669302 loss: 9.780804
# 1599 a: -0.35583335 b: 15.669302 loss: 9.780804
# 1699 a: -0.3558334 b: 15.669303 loss: 9.780804
# 1799 a: -0.3558334 b: 15.669304 loss: 9.780804
# 1899 a: -0.3558333 b: 15.669305 loss: 9.780805
# 1999 a: -0.35583323 b: 15.669305 loss: 9.780804

# %% [markdown]
# hyper parameter: 학습률, 배치 크기처럼 사용자가 임의로 지정해야 하는 값

# %%
# NonLinear Regression
## Polynomial Regression

X = [0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
Y = [12.27, 14.44, 11.87, 18.75, 17.52, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

a = tf.Variable(random.random())
b = tf.Variable(random.random())
c = tf.Variable(random.random())

def compute_loss():
    y_pred = a*X*X + b*X + c
    loss = tf.reduce_mean((Y-y_pred)**2)
    return loss

optimizer = tf.optimizers.Adam(lr=0.07)
for i in range(2000):
    optimizer.minimize(compute_loss, var_list=[a,b,c])
    
    if i % 100 == 99:
        print(i, 'a:', a.numpy(), 'b:', b.numpy(), 'c:', c.numpy(), 'loss:', compute_loss().numpy())

line_x = np.arange(min(X), max(X), 0.01)
line_y = a * line_x * line_x + b * line_x + c


plt.plot(line_x,line_y,'r-')
plt.plot(X,Y,'bo')
plt.xlabel('Population Growth Rate (%)')
plt.ylabel('Elderly Population Rate (%)')
plt.show()
# Out:
# 99 a: 3.8293529 b: -5.516981 c: 6.6117435 loss: 66.81041
# 199 a: 2.7884579 b: -4.533732 c: 10.355098 loss: 31.126156
# 299 a: 1.2956249 b: -2.3106701 c: 12.932331 loss: 16.056831
# 399 a: 0.33931386 b: -0.8776069 c: 14.558181 loss: 11.01799
# 499 a: -0.17710368 b: -0.10410501 c: 15.438153 loss: 9.743296
# 599 a: -0.4182799 b: 0.2571032 c: 15.849295 loss: 9.497072
# 699 a: -0.51604867 b: 0.40353015 c: 16.015972 loss: 9.460626
# 799 a: -0.5505043 b: 0.45513284 c: 16.07472 loss: 9.456492
# 899 a: -0.56105685 b: 0.47093648 c: 16.092707 loss: 9.456137
# 999 a: -0.56384933 b: 0.47511947 c: 16.097467 loss: 9.456112
# 1099 a: -0.56448656 b: 0.47607288 c: 16.098555 loss: 9.456111
# 1199 a: -0.56461126 b: 0.47626257 c: 16.098759 loss: 9.456112
# 1299 a: -0.5646112 b: 0.47626206 c: 16.098759 loss: 9.45611
# 1399 a: -0.56461203 b: 0.4762634 c: 16.09876 loss: 9.45611
# 1499 a: -0.56461316 b: 0.4762649 c: 16.098763 loss: 9.45611
# 1599 a: -0.564615 b: 0.47626746 c: 16.098766 loss: 9.456111
# ...

# %% [markdown]
# 3차 이상으로 차원을 늘려볼 수도 있고, 다항 회귀에서 더 나아가 비선형 회귀를 적용해볼 수도 있음.
# 분수, 지수, e^x, logx 등을 회귀식에 추가해보는 것.
# 최적의 회귀식을 찾기 위해 노력해야 함.

# %%
# Regression with DeepLearning

import tensorflow as tf
import numpy as np

X = [0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
Y = [12.27, 14.44, 11.87, 18.75, 17.52, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=6, activation='tanh', input_shape=(1,)),
    tf.keras.layers.Dense(units=1)
])

model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.1), loss='mse')
model.summary()

history = model.fit(X, Y, epochs=10)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 6)                 12
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# ...
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1/1 [==============================] - 0s 213ms/step - loss: 255.2876
# Epoch 2/10
# 1/1 [==============================] - 0s 3ms/step - loss: 102.1272
# Epoch 3/10
# 1/1 [==============================] - 0s 2ms/step - loss: 11.7293
# Epoch 4/10
# 1/1 [==============================] - 0s 2ms/step - loss: 10.1014
# Epoch 5/10
# 1/1 [==============================] - 0s 2ms/step - loss: 9.8491
# Epoch 6/10
# 1/1 [==============================] - 0s 2ms/step - loss: 9.7636
# Epoch 7/10
# ...

# %% [markdown]
# tanh: 하이퍼볼린 탄젠트 함수, 실수 입력을 받아 -1과 1 사이 출력 반환
# mse(loss): 평균 제곱 오차

# %%
model.predict(X)
# Out:
# array([[15.8369875],
#        [15.695094 ],
#        [15.463529 ],
#        [15.853742 ],
#        [15.555774 ],
#        [15.843903 ],
#        [15.834405 ],
#        [15.7907295],
#        [15.698791 ],
#        [15.812705 ],
#        [15.6681385],
#        [15.804457 ],
#        [15.830098 ],
#        [15.853659 ],
#        [15.70245  ],
#        [14.016299 ]], dtype=float32)

# %%
import matplotlib.pyplot as plt

line_x = np.arange(min(X), max(X), 0.01)
line_y = model.predict(line_x)

plt.plot(line_x, line_y, 'r-')
plt.plot(X, Y, 'bo')
plt.xlabel('Population Growth Rate')
plt.ylabel('Elderly Population Rate')
plt.show()

# %%
#보스턴 주택 가격 데이터 세트 회귀

from tensorflow.keras.datasets import boston_housing
(train_X, train_Y), (test_X, test_Y) = boston_housing.load_data()

print(len(train_X), len(test_X))
print(train_X[0])
print(train_Y[0])
# Out:
# 404 102
# [  1.23247   0.        8.14      0.        0.538     6.142    91.7
#    3.9769    4.      307.       21.      396.9      18.72   ]
# 15.2

# %% [markdown]
# 훈련 데이터: 학습 과정에 사용되는 데이터
# 테스트 데이터: 학습 결과를 평가하기 위한 데이터
# 검증 데이터: 훈련 데이터의 일부를 떼어내서 학습이 잘 되고 있는지 검증하는 용도로 사용하는 데이터

# %%
#Standardization

x_mean = train_X.mean(axis=0)
x_std = train_X.std(axis=0)
train_X -= x_mean
train_X /= x_std
test_X -= x_mean
test_X /= x_std

y_mean = train_Y.mean(axis=0)
y_std = train_Y.std(axis=0)
train_Y -= y_mean
train_Y /= y_std
test_Y -= y_mean
test_Y /= y_std

print(train_X[0])
print(train_Y[0])
# Out:
# [-0.27224633 -0.48361547 -0.43576161 -0.25683275 -0.1652266  -0.1764426
#   0.81306188  0.1166983  -0.62624905 -0.59517003  1.14850044  0.44807713
#   0.8252202 ]
# -0.7821526033779157

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=52, activation='relu', input_shape=(13,)),
    tf.keras.layers.Dense(units=39, activation='relu'),
    tf.keras.layers.Dense(units=26, activation='relu'),
    tf.keras.layers.Dense(units=1)
])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.07), loss='mse')

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 52)                728
# _________________________________________________________________
# dense_3 (Dense)              (None, 39)                2067
# _________________________________________________________________
# dense_4 (Dense)              (None, 26)                1040
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 27
# ...
# Total params: 3,862
# Trainable params: 3,862
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 레이어의 수와 은닉층의 뉴런 수를 늘리면 모델의 표현력이 좋아지기 때문에 더 복잡한 내용 학습 가능
# ReLU: 여러 개의 레이어를 겹쳐서 사용할 때 시그모이드 함수나 tanh보다 좋은 결과를 얻을 수 있다.

# %%
history = model.fit(train_X, train_Y, epochs=25, batch_size=32, validation_split=0.25)
# Out:
# Epoch 1/25
# 10/10 [==============================] - 1s 50ms/step - loss: 4.0107 - val_loss: 0.6921
# Epoch 2/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4666 - val_loss: 0.4254
# Epoch 3/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3555 - val_loss: 0.3039
# Epoch 4/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2066 - val_loss: 0.3056
# Epoch 5/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2161 - val_loss: 0.2590
# Epoch 6/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2238 - val_loss: 0.3399
# Epoch 7/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1633 - val_loss: 0.3106
# Epoch 8/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1938 - val_loss: 0.2786
# Epoch 9/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1447 - val_loss: 0.2250
# Epoch 10/25
# ...

# %%
#학습 결과 시각화

import matplotlib.pyplot as plt

plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# 테스트 데이터를 이용해 회귀 모델 평가

model.evaluate(test_X, test_Y)
# Out:
# 4/4 [==============================] - 0s 812us/step - loss: 0.4051
# 0.40505272150039673

# %%
#실제 주택 가격과 예측 주택 가격을 1:1로 시각화

import matplotlib.pyplot as plt

pred_Y = model.predict(test_X)

plt.figure(figsize=(5,5))
plt.plot(test_Y, pred_Y, 'b.')
plt.axis([min(test_Y), max(test_Y), min(test_Y), max(test_Y)])

# y=x에 해당하는 대각선
plt.plot([min(test_Y), max(test_Y)], [min(test_Y), max(test_Y)], ls="--", c=".3")
plt.xlabel('test_Y')
plt.ylabel('pred_Y')

plt.show()

# %% [markdown]
# ### 검증 데이터와 테스트 데이터에 대해 모두 좋은 예측 성적 내기
#
# val_loss가 높아지지 않도록, 즉 네트워크가 훈련 데이터에 과적합되지 않도록 학습 도중에 끼어들어서 학습을 멈춰야 함

# %%
#콜백 함수를 이용해 예측 성능 높이기

import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=52, activation='relu', input_shape=(13,)),
    tf.keras.layers.Dense(units=39, activation='relu'),
    tf.keras.layers.Dense(units=26, activation='relu'),
    tf.keras.layers.Dense(units=1)
])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.07), loss='mse')
history = model.fit(train_X, train_Y, epochs=25, batch_size=32, validation_split=0.25, 
                    callbacks=[tf.keras.callbacks.EarlyStopping(patience=3, monitor='val_loss')])
# Out:
# Epoch 1/25
# 10/10 [==============================] - 0s 22ms/step - loss: 3.9076 - val_loss: 0.5843
# Epoch 2/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4502 - val_loss: 0.3631
# Epoch 3/25
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3480 - val_loss: 0.3971
# Epoch 4/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2434 - val_loss: 0.3808
# Epoch 5/25
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2622 - val_loss: 0.3893

# %% [markdown]
# ### 콜백 함수 리스트에 tf.keras.callbacks.EarlyStopping
# patience: 몇 번의 에포크를 기준으로 삼을 것인지
# monitor: 어떤 값을 지켜볼 것인지
#
# 위의 코드에서는 val_loss가 3회의 에포크를 수행하는 동안 최고 기록을 갱신하지 못한다면 학습을 멈춤

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
model.evaluate(test_X, test_Y)
# Out:
# 4/4 [==============================] - 0s 761us/step - loss: 0.2154
# 0.2153693586587906

# %%
import matplotlib.pyplot as plt

pred_Y = model.predict(test_X)

plt.figure(figsize=(5,5))
plt.plot(test_Y, pred_Y, 'b.')
plt.axis([min(test_Y), max(test_Y), min(test_Y), max(test_Y)])

# y=x에 해당하는 대각선
plt.plot([min(test_Y), max(test_Y)], [min(test_Y), max(test_Y)], ls="--", c=".3")
plt.xlabel('test_Y')
plt.ylabel('pred_Y')

plt.show()
